# %% [markdown]
# # Wald Agent Reference Demo
#
# This notebook shows how to run the agent over the sample document corpus.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parent
sys.path.insert(0, str(PROJECT_ROOT / "src"))

# %%
from wald_agent_reference import WaldAgentReference

agent = WaldAgentReference()
response = agent.ask(
    question='Which factors influence sales conversion for the company?',
    docs_path='../data/raw',
    generate_plot=True,
)
print(response.to_markdown())
# Out:
# Question
# Which factors influence sales conversion for the company?
#
# Executive Summary
# Revenue has the highest Q1 2024 value at 120.00.
#
# Key Findings
# 1. Ranking uses `Q1 2024` from sheet `Sheet1`.
# 2. Revenue = 120.00
# 3. Operating Margin = 18.00
#
# Calculations Performed
# - Dimension column: Metric
# - Metric column: Q1 2024
# - Source workbook/table: revenue_trend.csv / Sheet1
#
# Evidence
# - annual_report_2024.md: # Annual Report 2024 The company closed 2024 with stronger enterprise demand and a healthier product mix. Leadership noted that revenue expanded steadily over the year, driven by the enterprise and digital media segments...
# - q2_operational_update.md: # Q2 Operational Update Quarterly operations improved in engineering and sales, while support and finance continued to lag target performance. Key highlights: - Sales conversion improved after pricing simplification. - E...
# - department_scorecard.csv [Sheet1]: Spreadsheet department_scorecard.csv sheet Sheet1. Columns: Department, Performance Score, Margin, Revenue, Target Score. Preview rows: Sales | 88 | 29 | 68 | 85 Engineering | 84 | 22 | 55 | 82 Support | 61 | 12 | 24 | 8...
# - risk_register.csv [Sheet1]: Spreadsheet risk_register.csv sheet Sheet1. Columns: Risk Category, Severity, Status, Owner. Preview rows: Support Bottleneck | High | Open | Operations Contractor Dependence | Medium | Open | Support Forecast Accuracy |...
# - revenue_trend.csv [Sheet1]: Spreadsheet revenue_trend.csv sheet Sheet1. Columns: Metric, Q1 2024, Q2 2024, Q3 2024, Q4 2024. Preview rows: Revenue | 120 | 138 | 140 | 160 Operating Margin | 18 | 20 | 19 | 22...
#
# Visual Insights
# - Q1 2024 by Metric chart saved to outputs/plots/which-factors-influence-sales-conversion-for-the-company.png.
#
# Risks / Caveats
# - No caveats.
#
# Source References
# - annual_report_2024.md
# - q2_operational_update.md
# - department_scorecard.csv [Sheet1]
# - risk_register.csv [Sheet1]
# - revenue_trend.csv [Sheet1]
