# %% [markdown]
# # Wald Agent Reference Demo
#
# This notebook shows how to run the agent over the sample document corpus.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parent
sys.path.insert(0, str(PROJECT_ROOT / "src"))

# %%
from wald_agent_reference import WaldAgentReference

agent = WaldAgentReference()
response = agent.ask(
    question='Which factors influence sales conversion for the company?',
    docs_path='../data/raw',
    generate_plot=True,
)
print(response.to_markdown())
# Out:
# 2026-04-02 08:41:24 | INFO | wald_agent_reference.core.agent | Received question: Which factors influence sales conversion for the company?
# 2026-04-02 08:41:24 | INFO | wald_agent_reference.core.agent | Planner route sequence: retrieval
# 2026-04-02 08:41:24 | INFO | wald_agent_reference.ingestion.ingest | Folder ingestion complete for ../data/raw
# 2026-04-02 08:41:24 | INFO | wald_agent_reference.core.agent | Ingestion completed | documents=5 chunks=22 tables=11 visuals=1
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       1 from wald_agent_reference import WaldAgentReference
#       3 agent = WaldAgentReference()
# ----> 4 response = agent.ask(
#       5     question='Which factors influence sales conversion for the company?',
#       6     docs_path='../data/raw',
#       7     generate_plot=True,
#       8 )
# ...
